# %% [markdown]
# # <a href="https://miptstats.github.io/courses/ad_fivt.html">Введение в анализ данных</a>
# ## Домашнее задание 1. Простой анализ данных.

# %% [markdown]
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
#
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины. Правила переноса дедлайнов определены в презентации с первого занятия.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Задачи 1 и 2 сдаются в систему Яндекс.Контест. Ссылка на контест в телеграм-боте.
#
#
# **Сдача задачи 3:**
#
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_ds24_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. Дождитесь подтверждения от бота, что он принял файл. Если подтверждения нет, то что-то не так. **Работы, присланные иным способом, не принимаются.**
# * Прислать нужно **ноутбук в формате `ipynb`**.
# * Телеграм не разрешает боту получать файлы более **20 Мб**. Если ваше решение весит больше, *заранее* разделите ноутбук на несколько.
# * Для выполнения задания **используйте этот ноутбук в качестве основы, ничего не удаляя из него**. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
# * **Код из рассказанных на занятиях ноутбуков** можно использовать без ограничений.
#
# **Перед выполнением задания посмотрите презентацию по выполнению и оформлению домашних заданий с занятия 1.**
#
# ---
#
# **Баллы за задание:**
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 1 &mdash; 10 баллов
# * Задача 2 &mdash; 10 баллов
# * Задача 3 &mdash; 80 баллов
#
#
# Баллы учитываются в <b>обязательной части</b> курса и не влияют на оценку по факультативной части.

# %%
# Bot check

# HW_ID: fpmi_ad1
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то

# Status: final
# Перед отправкой в финальном решении удали "not" в строчке выше
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid', font_scale=1.3, palette='Set2')

# %% [markdown]
# ### <font color="blue"><i>Легкая часть</i></font>
#
# ### Задача 1.
#
# Условие задачи и сдача в системе Яндекс.Контест. Ссылка на контест в телеграм-боте.

# %% [markdown]
# ---
# ### Задача 2.
#
# Условие задачи и сдача в системе Яндекс.Контест. Ссылка на контест в телеграм-боте.

# %% [markdown]
# ---
# ### Задача 3.

# %% [markdown]
# Титаник был крупнейшим пассажирским судном в 1912—1913 годах. Во время первого рейса затонул в северной Атлантике, столкнувшись с айсбергом в ночь с 14 на 15 апреля 1912 года, при этом погибло 1502 из 2224 пассажиров и членов экипажа. Данные о пассажирах были собраны в таблицы, которые можно скачать с <a href="https://www.kaggle.com/c/titanic/data" target="_blank">Kaggle</a>. Эти данные часто используются в качестве обучающих в анализе данных.

# %% [markdown]
# На дополнительном занятии 10 февраля будет показан простой пример работы с датасетом Титаник. Сейчас ваша задача &mdash; на основе простого анализа предоставленных данных обучить несколько классификаторов для определения выживших, иначе говоря, получить некоторые приближенные правила определения, выжил пассажир или нет, а также сравнить эти правила по качеству приближения.
#
# #### 1. Подготовка данных
#
# Загрузите данные с помощью `pandas`.

# %%
data = pd.read_csv('train.csv', index_col=0)
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# Для начало классифицируем пассажиров по возрасту. \
# Классификация пассажиров по возрасту:

# %%
data["AgeGroup"] = pd.cut(
    data["Age"],
    bins=pd.IntervalIndex.from_tuples([(0, 9), (9, 18), (18, 25), (25, 50), (50, 100)]),
)

groups = {
    "(0, 9]": "Младенец",
    "(9, 18]": "Подросток",
    "(18, 25]": "Молодой",
    "(25, 50]": "Зрелый",
    "(50, 100]": "Старик",
}

data["AgeGroup"] = data["AgeGroup"].apply(lambda x: groups[str(x)])

# %% [markdown]
# Разделите данные по строкам на две части случайным образом в соотношении 7:3. Первую часть мы будем называть *обучающей*, а вторую &mdash; *тестовой*.

# %%
train = data.sample(frac=0.7, random_state=1)
test = data.drop(train.index.values)

# %% [markdown]
# Из каждой части оставим несколько признаков, с которыми мы будем работать, а также отдельно &mdash; целевой признак. Примените к обеим частям таблицы функцию ниже

# %%
features_columns = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'AgeGroup']
target_column = 'Survived'  # Целевой признак

def get_features_and_target(data):
    features = data[features_columns]
    target = data[target_column]
    return features, target

# %%
features_train, target_train = get_features_and_target(train)
features_test, target_test = get_features_and_target(test)

# %% [markdown]
# #### 2. Исследование
#
# **Внимание.** Эта часть задачи должна выполняться *исключительно на обучающих данных*. За использование тестовых данных решение не будет оценено.
#
# Проведите визуальный анализ данных чтобы понять, как различные признаки влияют на целевой. Исследовать можно не целиком обучающие данные, а разделить их на две части по одному из признаков, а далее рассматривать каждую часть отдельно.
#
# *Не забывайте про информативность и эстетичность графиков.*

# %% [markdown]
# **Рассмотрим влияние различных категорий, на целевой признак.**

# %% [markdown]
# **Возраст.**
# Рассмотрим таблицу выживаемости человека от возраста.

# %% [markdown]
# подсчет процента выживших для каждой возрастной группы

# %%
train["AgeGroupPercent"] = train.groupby(["AgeGroup"])["Survived"].transform("mean")

# %%
with sns.axes_style("dark"):
    plt.figure(figsize=(9, 5))

    sns.barplot(data=train, x="AgeGroup", y="AgeGroupPercent", color="lightgreen").set(
        xlabel="Группировка по возраст",
        ylabel="Процент выживших",
        title="Таблица зависимости выживаемости от возраста пассажира",
    )

# %% [markdown]
# Похоже, быть моложе повышало шансы на выживание, хотя взаимосвязь не так четко выражена.

# %% [markdown]
# **Пол и класс следования**. Рассмотрим, как эти факторы влияют на выживаемость человека.

# %%
with sns.axes_style("dark"):
    plt.figure(figsize=(13, 7))

    plt.subplot(1, 2, 1)
    sns.barplot(data=train, x="Pclass", y="Survived", hue="Sex", palette="Set3").set(
        xlabel="Классы следования",
        ylabel="Процент выживших",
        title="Таблица зависимости выживаемости \n от класса пассажира и пола",
    )

    plt.subplot(1, 2, 2)
    sns.barplot(data=train, x="Pclass", y="Survived", color="lightblue").set(
        xlabel="Классы следования",
        ylabel="Процент выживших",
        title="Таблица зависимости выживаемости \n от класса пассажира",
    )

# %% [markdown]
# Стало очевидно, что чем выше класс пассажира, тем больше у него шансов выжить. \
# Причем, любая женщина, имея 1 или 2 класс, почти наверняка выживала, а имея 3 класс, имела больше шансов выжить, чем мужчины любых классов.

# %% [markdown]
# **Классы пассажиров и цена билета.** Кажется, эти параметры сильно взаимосвязаны.

# %%
with sns.axes_style("dark"):
    plt.figure(figsize=(13, 7))

    plt.subplot(1, 2, 1)
    sns.barplot(data=train, x="Pclass", y="Fare", hue="Sex", palette="Set2").set(
        xlabel="Классы следования",
        ylabel="Цена билета",
        title="Таблица зависимости класса пассажира \n от цены билета",
    )

    plt.subplot(1, 2, 2)
    sns.lineplot(data=train, y="Fare", x="Survived").set(
        xlabel="Процент выживших",
        ylabel="Цена билета",
        title="Таблица зависимости выживаемости \n от цены билета",
    )

# %% [markdown]
# Видно, что шансы выжить коррелируют с ценой на билет, также цена на билет коррелирует с классом пассажира, причем чем выше цена, тем выше класс.

# %% [markdown]
# **Параметры SibSp, Parch.**

# %% [markdown]
# Построим таблицу выживших при разных значениях SibSp и Parch.

# %%
sibsp_and_parch = pd.pivot_table(
    train, values="Survived", index="SibSp", columns="Parch"
)

# %%
with sns.axes_style("dark"):
    plt.figure(figsize=(9, 10))
    sns.heatmap(
        sibsp_and_parch, cmap="RdPu", annot=True, cbar_kws={"orientation": "horizontal"}
    ).set(
        ylabel="Количество братьев/сестер",
        xlabel="Количество детей/родителей",
        title="Доля выживших в зависимости от количества детей/родителей \n и от количества братьев/сестер",
    )

# %% [markdown]
# Рассмотрим отдельно эти параметры.

# %%
with sns.axes_style("dark"):
    plt.figure(figsize=(13, 7))

    plt.subplot(1, 2, 1)
    sns.barplot(data=train, x="SibSp", y="Survived", color="lightgreen").set(
        xlabel="Количество братьев/сестер",
        ylabel="Процент выживших",
        title="Таблица зависимости выживаемости \n от количество братьев/сестер",
    )

    plt.subplot(1, 2, 2)
    sns.barplot(data=train, x="Parch", y="Survived", color="lightblue").set(
        xlabel="Количество детей/родителей",
        ylabel="Процент выживших",
        title="Таблица зависимости выживаемости \n от количество детей/родителей",
    )

# %% [markdown]
# Здесь можно сделать вывод, что иметь слишком много родных отрицательно сказывается на выживаемости пассажира.

# %% [markdown]
# #### 3. Классификация методом ближайшего соседа
#
# Ранее в контесте вы уже реализовали функцию поиска ближайших соседей. Теперь давайте применим ее для решения нашей текущей задачи.
#
# Реализуйте функцию, которая для каждого объекта тестового набора данных найдет $k$ ближайших соседей из обучающего набора данных, и в качестве ответа возьмет наиболее часто встречающееся значение целевого признака среди найденных соседей. Обратите внимание, что соседей необходимо искать только среди объектов обучающего набора данных.

# %%
def find_nearest_points(A: np.ndarray, B: np.ndarray, k: int) -> np.ndarray:
    distance_matrix = ((A[:, np.newaxis, :] - B) ** 2).sum(axis=2)

    distance_matrix = np.argsort(distance_matrix, axis=0)
    distance_matrix += 1

    return distance_matrix[0:k, :].T

# %%
def normalize(features):
    """
    Нормализирует по среднему значению в массиве.
    """
    features["Age"] = features["Age"] / features["Age"].mean()
    features["Fare"] = features["Fare"] / features["Fare"].mean()

# %%
def knn(features, train_features, train_target, k=1):
    """
    Предсказание целевого признака для данных features -- pandas-таблица данных.
    на основе обучающего набора данных train_features, train_target.
    Возвращает pandas.Series с теми же индексами, что и у features.
    Число k -- количество соседей.
    """
    # Нормализация
    normalize(features)
    normalize(train_features)

    # строим матрицу ближайших точек
    matrix_nearest_points = find_nearest_points(
        train_features[["Age", "Fare"]].to_numpy(),
        features[["Age", "Fare"]].to_numpy(),
        k,
    )
    # для удобства
    matrix_nearest_points = pd.DataFrame(matrix_nearest_points)
    matrix_nearest_points.index = features.index

    # меняем индесацию ибо функция find_nearest_points не учитывает индескацию, и работает с чистыми numpy массивами
    train_target.index = np.arange(1, len(train_target) + 1)

    # метод knn
    i = 0
    predicted = np.empty(features.shape[0], dtype=bool)

    for nearest_point in matrix_nearest_points.to_numpy():
        # число выживших соседей
        survived_count = 0

        for index in nearest_point:
            survived_count += train_target[index]

        predicted[i] = 2 * survived_count >= k
        i += 1

    return pd.Series(predicted, features.index)

# %% [markdown]
# Постройте классификатор методом ближайшего соседа, используя только признаки `Age` и `Fare`.
#
# Какую метрику (функцию расстояния) вы при этом используете? Нужно ли предварительно что-то сделать с признаками?

# %% [markdown]
# Тут используется евклидова метрика. Причем я предварительно нормирую данные, иначе параметр ```Fare``` имел бы больший вес, чем ```Age```.

# %%
print(features_train["Fare"].mean())
print(features_train["Age"].mean())
# Out:
# 34.02572051282051
# 29.356699801192843

# %% [markdown]
# Как меняется результат классификации при другом количестве соседей? Рассмотрите хотя бы три различных нечетных значения количества соседей.

# %%
res1 = knn(features_test.copy(), features_train.copy(), target_train.copy(), 1)
res2 = knn(features_test.copy(), features_train.copy(), target_train.copy(), 9)
res3 = knn(features_test.copy(), features_train.copy(), target_train.copy(), 11)

print("Число выживших: ", res1.sum())
print("Число выживших: ", res2.sum())
print("Число выживших: ", res3.sum())
# Out:
# Число выживших:  142
# Число выживших:  135
# Число выживших:  140

# %% [markdown]
# Как можно было бы учесть другие признаки? Какие при этом могут возникнуть проблемы?
#
# Параметры ```SibSp```, ```Parch```, ```Pclass``` тоже числовые. Их бы пришлось только отнормировать. То же самое относится к параметру ```Sex```, если значения воспринимать как 1/0. \
# Другое дело - насколько эти параметры равноценны. Думаю, не плохо бы ввести веса для этих параметров как гиперпараметр.
#
# Строить классификатор с другими признаками при этом не нужно.

# %% [markdown]
# #### 4. Классификация логическими правилами
#
# На основе выше проведенного исследования предложите два разных правила в виде решающего дерева, пример которого можете посмотреть в презентации с первой лекции (классификация котиков). Никакие статистические методы использовать не требуется, только логику и графики.
#
# В данной задаче достаточно, если первое дерево будет иметь максимальную глубину 2, а второе &mdash; глубину 1, и при этом не является поддеревом первого. *Примечание*: дерево из одного листа имеет глубину 0.
#
# **Дерево 1:**
# ```
#                 Билет стоил больше 50
#              +-----------------------> Выжил
#              !
# Пассажир ----+
#              !  Билет стоил меньше 50
#              +-----------------------> Погиб
# ```
# **Дерево 2:**
# ```
#                            1 или 2 класс
#                         +----------------> Выжил
#                 Женщина !
#              +----------+
#              !          !     3 класс
#              !          +----------------> Погиб
#              !
# Пассажир ----+
#              !              Молодой
#              !          +-------------> Выжил
#              !  Мужчина !
#              +----------+
#                         !   Немолод
#                         +--------------> Погиб
# ```
#
# Реализуйте полученные деревья по шаблону

# %%
def tree1(features):
    """
    Предсказание целевого признака для данных features -- pandas-таблица данных.
    Возвращает pandas.Series с теми же индексами, что и у features.
    """
    ans = pd.Series(np.where(features["Fare"] >= 50, True, False))
    ans.index = features.index
    return ans

# %%
def tree2(features):
    """
    Предсказание целевого признака для данных features -- pandas-таблица данных.
    Возвращает pandas.Series с теми же индексами, что и у features.
    """
    arr = np.empty(features.shape[0], dtype=bool)

    # Решающее дерево
    arr[:] = np.where(
        ((features["Sex"] == "female") & (features["Pclass"] != 3))
        | (
            (features["Sex"] != "female")
            & (
                (features["AgeGroup"] == "Подросток")
                | (features["AgeGroup"] == "Младенец")
            )
        ),
        True,
        False,
    )

    ans = pd.Series(arr)
    ans.index = features.index
    return ans

# %% [markdown]
# #### 5. Качество
#
# Вспомним, что у нас имеется тестовая часть выборки. Самое время ее использовать для того, чтобы оценить, насколько хорошими получились деревья. Предложите какой-нибудь критерий качества.
#
# *Замечание*. Не стоит пытаться искать, какие критерии существуют. В данном случае легко предложить адекватный критерий. Стандартные критерии мы разберем позже, но для начала лучше подумать самостоятельно.
#
# **Критерий:**
#
# Находим число "Правильных ответов" и делим на количество вопросов. Тут под "правильными ответами" понимаются ситуации, когда мы угадали судьбу человека, то есть, выжил ли он или нет.
#
# Реализуйте данный критерий по шаблону

# %%
def criteria(target, predicted):
    '''
    Вычисление критерия качества для предсказания predicted, 
    если истинные значения -- target.
    Возвращает одно вещественное число.
    '''
    incorrect_answers = (target ^ predicted).sum()
    right_answer = len(target) - incorrect_answers
    return right_answer / len(target)

# %% [markdown]
# Оцените качество построенных ранее моделей (два дерева, kNN), используя предложенный критерий.
#
# *Примечание.* Полученные значения не влияют на оценку по задание. Оценивается только корректность и обоснованность решения, а также графики и выводы.

# %% [markdown]
# Оценка качества для решающих деревьев.

# %%
evaluation_for_tree1 = criteria(target_test, tree1(features_test))
evaluation_for_tree2 = criteria(target_test, tree2(features_test))

print(f"Оценка качества первого дерева: {evaluation_for_tree1 :.2%}")
print(f"Оценка качества второго дерева: {evaluation_for_tree2 :.2%}")
# Out:
# Оценка качества первого дерева: 70.79%
# Оценка качества второго дерева: 77.53%

# %% [markdown]
# Посчитайте значение предложенного ранее критерия качества для метода ближайшего соседа для значений $k$ от 1 до 10. Постройте график зависимости критерия качества от $k$. Как вы можете пояснить полученные результаты?

# %% [markdown]
# Оценим модель KNN для к = 0, ... , 10

# %%
def test_model(test_count):
    evaluation_for_knn = np.array([criteria(target_test, knn(features_test.copy(), features_train.copy(), target_train.copy(), i)) for i in range(1, test_count + 1)])

    #  Для удобства
    evaluation_for_knn = pd.DataFrame(evaluation_for_knn, index=np.arange(1, test_count + 1), columns=["Result"])
    return evaluation_for_knn

# %%
with sns.axes_style("darkgrid"):
    evaluation_for_knn = test_model(10)
    plt.figure(figsize=(12, 6))

    sns.lineplot(data=evaluation_for_knn, x=evaluation_for_knn.index, y="Result").set(
        xlabel="Значение k",
        ylabel="Точность Модели",
        title="Точность модели в зависимости от K",
    )

    plt.show()

# %% [markdown]
# Поведение модели при первых 100 значениях k.

# %%
with sns.axes_style("darkgrid"):
    evaluation_for_knn = test_model(100)
    plt.figure(figsize=(12, 6))

    sns.lineplot(data=evaluation_for_knn, x=evaluation_for_knn.index, y="Result").set(
        xlabel="Значение k",
        ylabel="Точность Модели",
        title="Точность модели в зависимости от K",
    )

    plt.show()

# %% [markdown]
# Видно, что при первых 10 значениях модель не лучший вариант, который просто выдает случайный результат. Это можно объяснить тем, что этот метод в целом не очень подходит для данной задачи. Как минимум, стоило бы ввести веса параметров, так как, как мы видели в части исследования, не все параметры равнозначно влияют на результат.
#
# Что касается поведения на первых 100 значениях, то думаю, здесь уже сработал тот факт, что в целом параметры ```Fare``` и ```Age``` коррелируют с выживаемостью. При k >= 50 мы уже сверяемся почти со всеми данными в датасете.

# %% [markdown]
# #### 6. Выводы

# %% [markdown]
# Исследования показали, что выживаемость в основном зависит от пола, стоимости билета и класса пассажира. Остальные параметры влияют на выживаемость не так сильно:
# * Все женщины в 1-2 классе выжили.
# * Почти все пассажиры со стоимостью билета больше 70 выжили.
# * Также почти все младенцы выжили.
# * Исследования также показали, что у всех, у кого было 4-5 родственников на корабле, все они погибли.
#
# На основе результатов исследования были построены решающие деревья, которые показали успех:
# * 70% точности у первого дерева и 77% точности у второго.
#
# Была построена модель на основе метода k-Nearest Neighbors (knn):
# * Модель показывает неплохие результаты при k >= 40, около 75% точности.
# * На более мелких значениях k модель показывает себя достаточно плохо, немного выше 60%.
#
# Также был введен критерий оценки моделей. По моему мнению, он достаточно интуитивный и идеально подходит для решения данной задачи.
